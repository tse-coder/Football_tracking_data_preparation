# %% [markdown]
# ## Download video dataset using soccer net
# required package: ***SoccerNet***

# %%
import SoccerNet
from SoccerNet.Downloader import SoccerNetDownloader

# %%
my_downloader = SoccerNetDownloader(LocalDirectory="../data/raw_videos")
my_downloader.password = "s0cc3rn3t"
my_downloader.downloadGames(files=["1_720p.mkv", "2_720p.mkv"], split=["train", "valid", "test"])
